# %%
import tensorflow as tf 
import numpy as np

# %%
# Definindo uma constante 

tensor = tf.constant([[23,44] ,[40, 12]])

# %%
tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[23, 44],
#        [40, 12]], dtype=int32)>

# %%
# Definindo uma variável 

var = tf.Variable([[12, 13], [40, 60], [89, 33]])
var
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[12, 13],
#        [40, 60],
#        [89, 33]], dtype=int32)>

# %%
var2 = tf.Variable("Testando texto", dtype="string")

# %%
var2
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=string, numpy=b'Testando texto'>

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
const = tf.constant([[29, 30], [40, 10]])

# %%
const
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[29, 30],
#        [40, 10]], dtype=int32)>

# %%
const.shape
# Out:
# TensorShape([2, 2])

# %%
# Acessando o tensor com numpy 
const.numpy()
# Out:
# array([[29, 30],
#        [40, 10]], dtype=int32)

# %%
# operação com tensores 
const + 4
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[33, 34],
#        [44, 14]], dtype=int32)>

# %%
tensor = tf.constant([[10, 12], [20, 25]])

# %%
tensor * 3
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[30, 36],
#        [60, 75]], dtype=int32)>

# %%
# tensor elevado ao quadrado 
np.square(tensor)
# Out:
# array([[100, 144],
#        [400, 625]], dtype=int32)

# %%
# raiz quadrada do tensor 
np.sqrt(tensor)
# Out:
# array([[3.16227766, 3.46410162],
#        [4.47213595, 5.        ]])

# %%
tensor_2 = tf.constant([[20, 11], [58, 23]])

# %%
# produto escalar entre dois tensores 
np.dot(tensor, tensor_2)
# Out:
# array([[ 896,  386],
#        [1850,  795]], dtype=int32)

# %%
tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[10, 12],
#        [20, 25]], dtype=int32)>

# %%
tensor_2
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[20, 11],
#        [58, 23]], dtype=int32)>

# %%
# String 
tf_string = tf.constant("TensorFlow String")
tf_string
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'TensorFlow String'>

# %%
# tamanho da string
tf.strings.length(tf_string)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=17>

# %%
# strings com representações numéricas 
tf.strings.unicode_decode(tf_string, "UTF8")
# Out:
# <tf.Tensor: shape=(17,), dtype=int32, numpy=
# array([ 84, 101, 110, 115, 111, 114,  70, 108, 111, 119,  32,  83, 116,
#        114, 105, 110, 103], dtype=int32)>

# %%
array_strings = tf.constant(["TensorFlow 2.0", "Deep learning", "AI"])

# %%
for string in array_strings:
  print(string)
# Out:
# tf.Tensor(b'TensorFlow 2.0', shape=(), dtype=string)
# tf.Tensor(b'Deep learning', shape=(), dtype=string)
# tf.Tensor(b'AI', shape=(), dtype=string)
