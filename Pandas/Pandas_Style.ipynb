# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
path = '/content/drive/My Drive/Inteligência Artificial - Notebooks /ML - Não supervisionado /Clustering/Mall_Customers.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# esconder colunas com pandas 
data.head().style.hide_index().hide_columns(['Gender', 'Age'])
# Out:
# <style  type="text/css" >
# </style><table id="T_c54c7918_c4b5_11ea_b148_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >CustomerID</th>        <th class="col_heading level0 col3" >Annual Income (k$)</th>        <th class="col_heading level0 col4" >Spending Score (1-100)</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c54c7918_c4b5_11ea_b148_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                                         <td id="T_c54c7918_c4b5_11ea_b148_0242ac1c0002row0_col3" class="data row0 col3" >15</td>
#                         <td id="T_c54c7918_c4b5_11ea_b148_0242ac1c0002row0_col4" class="data row0 col4" >39</td>
#             </tr>
#             <tr>
#                                 <td id="T_c54c7918_c4b5_11ea_b148_0242ac1c0002row1_col0" class="data row1 col0" >2</td>
# ...

# %%
# Colorir valores nulos
data.head(10).style.highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
# </style><table id="T_c551a622_c4b5_11ea_b148_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CustomerID</th>        <th class="col_heading level0 col1" >Gender</th>        <th class="col_heading level0 col2" >Age</th>        <th class="col_heading level0 col3" >Annual Income (k$)</th>        <th class="col_heading level0 col4" >Spending Score (1-100)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c551a622_c4b5_11ea_b148_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c551a622_c4b5_11ea_b148_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c551a622_c4b5_11ea_b148_0242ac1c0002row0_col1" class="data row0 col1" >Male</td>
#                         <td id="T_c551a622_c4b5_11ea_b148_0242ac1c0002row0_col2" class="data row0 col2" >19</td>
# ...

# %%
# Destaque para o valor MAX e MIN de cada coluna
data.head(10).style.highlight_max(color='yellow').highlight_min(color='lightblue')
# Out:
# <style  type="text/css" >
#     #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row0_col0 {
#             : ;
#             background-color:  lightblue;
#         }    #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row0_col2 {
#             : ;
#             background-color:  lightblue;
#         }    #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row0_col3 {
#             : ;
#             background-color:  lightblue;
#         }    #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row1_col3 {
#             : ;
#             background-color:  lightblue;
#         }    #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row7_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row8_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row8_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_c558da5a_c4b5_11ea_b148_0242ac1c0002row8_col4 {
#             : ;
# ...

# %%
# Gradient function para colunas numéricas s
data.head(10).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_c55dbcc8_c4b5_11ea_b148_0242ac1c0002row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c55dbcc8_c4b5_11ea_b148_0242ac1c0002row0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c55dbcc8_c4b5_11ea_b148_0242ac1c0002row0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c55dbcc8_c4b5_11ea_b148_0242ac1c0002row0_col4 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_c55dbcc8_c4b5_11ea_b148_0242ac1c0002row1_col0 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_c55dbcc8_c4b5_11ea_b148_0242ac1c0002row1_col2 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_c55dbcc8_c4b5_11ea_b148_0242ac1c0002row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %%
# ordenando valores com bar chart 
data.head(10).sort_values(by='Age').style.bar(color='lightblue')
# Out:
# <style  type="text/css" >
#     #T_c562df82_c4b5_11ea_b148_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_c562df82_c4b5_11ea_b148_0242ac1c0002row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_c562df82_c4b5_11ea_b148_0242ac1c0002row0_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_c562df82_c4b5_11ea_b148_0242ac1c0002row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 39.6%, transparent 39.6%);
#         }    #T_c562df82_c4b5_11ea_b148_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 22.2%, transparent 22.2%);
#         }    #T_c562df82_c4b5_11ea_b148_0242ac1c0002row1_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %%
# filtro de style com condições 
def colormap(value):
  if type(value) == type('object'):
    return 'color:blue'
  else:
    return 'color:red'


# identificando tipo de dados 
data.head(10).style.applymap(colormap)
# Out:
# <style  type="text/css" >
#     #T_c568e292_c4b5_11ea_b148_0242ac1c0002row0_col0 {
#             color: red;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row0_col1 {
#             color: blue;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row0_col2 {
#             color: red;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row0_col3 {
#             color: red;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row0_col4 {
#             color: red;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row1_col0 {
#             color: red;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row1_col1 {
#             color: blue;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row1_col2 {
#             color: red;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row1_col3 {
#             color: red;
#         }    #T_c568e292_c4b5_11ea_b148_0242ac1c0002row1_col4 {
#             color: red;
# ...

# %%
corte_analise = (data[(data['Age']>50) & (data['Annual Income (k$)']>4)])

# %%
corte_analise
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 8             9    Male   64                  19                       3
# 10           11    Male   67                  19                      14
# 12           13  Female   58                  20                      15
# 18           19    Male   52                  23                      29
# 24           25  Female   54                  28                      14
# 30           31    Male   60                  30                       4
# 32           33    Male   53                  33                       4
# 40           41  Female   65                  38                      35
# 53           54    Male   59                  43                      60
# 56           57  Female   51                  44                      50
# 57           58    Male   69                  44                      46
# 59           60    Male   53                  46                      46
# ...
